# %% [markdown]
# ### 📂 Importing Libraries and Loading Data
# Importing essential libraries for data analysis and visualization, and loading the **mental health dataset** into a DataFrame.
# `data`**.

# %%
import pandas as pd 
import numpy as np

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data=pd.read_csv("mentalhealthdataset.csv")

# %% [markdown]
# ### 🔍 Exploring the Dataset
# Performing initial exploration to check dataset structure, shape, missing values, and unique categories for key features.

# %%
#data.head()
# Out:
#    Gender  self_employed  family_history  treatment  Days_Indoors  \
# 0       0              0               0          1             1
# 1       0              0               1          1             1
# 2       0              0               1          1             1
# 3       0              0               1          1             1
# 4       0              0               1          1             1
#
#    Growing_Stress  Changes_Habits  Mental_Health_History  Mood_Swings  \
# 0               2               0                      2            1
# 1               2               0                      2            1
# 2               2               0                      2            1
# 3               2               0                      2            1
# 4               2               0                      2            1
#
#    Coping_Struggles  ...  Country_South Africa  Country_Sweden  \
# 0                 0  ...                     0               0
# ...

# %%
#data.info()

# %%
#data.shape

# %%
#data.isnull().sum()

# %%
#print(data['Gender'].unique())
#print(data['Country'].unique())
#print(data['Occupation'].unique())
#print(data['self_employed'].unique())
#print(data['family_history'].unique())
#print(data['treatment'].unique())
#print(data['Days_Indoors'].unique())
#print(data['Growing_Stress'].unique())
#print(data['Changes_Habits'].unique())
#print(data['Mental_Health_History'].unique())
#print(data['Mood_Swings'].unique())
#print(data['Coping_Struggles'].unique())
#print(data['Work_Interest'].unique())
#print(data['Social_Weakness'].unique())
#print(data['mental_health_interview'].unique())
#print(data['care_options'].unique())

# %% [markdown]
# ### 🧹 Data Cleaning
# Filling missing values, removing duplicates, and verifying that no null values remain in the dataset.

# %%
#data['self_employed'].value_counts(dropna=False)

# %%
data['self_employed']=data['self_employed'].fillna('No')

# %%
data['self_employed'].value_counts(dropna=False)
# Out:
# self_employed
# No     263196
# Yes     29168
# Name: count, dtype: int64

# %%
data.isnull().sum()
# Out:
# Timestamp                  0
# Gender                     0
# Country                    0
# Occupation                 0
# self_employed              0
# family_history             0
# treatment                  0
# Days_Indoors               0
# Growing_Stress             0
# Changes_Habits             0
# Mental_Health_History      0
# Mood_Swings                0
# Coping_Struggles           0
# Work_Interest              0
# Social_Weakness            0
# mental_health_interview    0
# care_options               0
# dtype: int64

# %%
print(data.isna().sum())
# Out:
# Timestamp                  0
# Gender                     0
# Country                    0
# Occupation                 0
# self_employed              0
# family_history             0
# treatment                  0
# Days_Indoors               0
# Growing_Stress             0
# Changes_Habits             0
# Mental_Health_History      0
# Mood_Swings                0
# Coping_Struggles           0
# Work_Interest              0
# Social_Weakness            0
# mental_health_interview    0
# care_options               0
# dtype: int64

# %%
data = data.drop_duplicates()

# %%
print(data.duplicated().any())
# Out:
# False

# %%
print(data.isna().sum())
# Out:
# Timestamp                  0
# Gender                     0
# Country                    0
# Occupation                 0
# self_employed              0
# family_history             0
# treatment                  0
# Days_Indoors               0
# Growing_Stress             0
# Changes_Habits             0
# Mental_Health_History      0
# Mood_Swings                0
# Coping_Struggles           0
# Work_Interest              0
# Social_Weakness            0
# mental_health_interview    0
# care_options               0
# dtype: int64

# %%
#data.shape

# %% [markdown]
# ### 📊 Data Visualization and Feature Relationships
# Visualizing feature distributions and exploring relationships between key variables to understand mental health patterns in the dataset.

# %%
#features= ['Gender','treatment','Mood_Swings','Growing_Stress','Mental_Health_History']
#fig, axes=plt.subplots(1,5, figsize=(20,5))

#for i,feature in enumerate(features) :
    #sns.countplot(x=feature,data=data,ax=axes[i])
    #axes[i].set_title(f'{feature} Distribution')

#plt.tight_layout()
#plt.show()

# %%
#plt.savefig("count_plots.png", dpi=300)

# %%
#features = ['Country', 'Occupation', 'self_employed', 'family_history', 'Days_Indoors',
            #'Changes_Habits', 'Work_Interest', 'Social_Weakness', 'mental_health_interview', 'care_options']
#fig, axes = plt.subplots(2, 5, figsize=(20, 12))
#axes = axes.flatten()
#for i, feature in enumerate(features):
    #sns.countplot(y=feature, data=data, ax=axes[i])
    #axes[i].set_title(f'{feature} Distribution')
    #axes[i].tick_params(axis='y', labelsize=10)

#plt.tight_layout()
#plt.show()

# %%
#plt.figure(figsize=(10,6))
#sns.countplot(x='Mental_Health_History', hue='treatment', data=data)

#plt.title('Treatment vs Mental Health History')
#plt.xlabel('Mental Health History (Yes/No)')
#plt.ylabel('Count')


#plt.show()

# %%
#plt.figure(figsize=(10,6))
#sns.countplot(x='Mood_Swings', hue='Mental_Health_History', data=data)

#plt.title('Mood_Swings vs Mental Health History')
#plt.xlabel('Mood Swings (Yes/No)')
#plt.ylabel('Count')

#plt.show()

# %%
#plt.figure(figsize=(10,6))
#sns.countplot(x='Mood_Swings', hue='Coping_Struggles', data=data)

#plt.title('Coping_Struggles vs Mood_Swings')
#plt.xlabel('Mood Swings (Yes/No/Maybe)')
#plt.ylabel('Count')

#plt.show()

# %%
#plt.figure(figsize=(10,6))
#sns.countplot(x='Mood_Swings', hue='Growing_Stress', data=data)

#plt.title('Mood_Swings vs Growing_Stress')
#plt.xlabel('Mood Swings (Low/Medium/High)')
#plt.ylabel('Count')

#plt.show()

# %%
#plt.figure(figsize=(10,6))
#sns.countplot(x='Mood_Swings', hue='Changes_Habits', data=data)

#plt.title('Change_Habits vs Mood_Swings')
#plt.xlabel('Mood Swings (Low/Medium/High)')
#plt.ylabel('Count')

#plt.show()

# %%
#plt.figure(figsize=(10,6))
#sns.countplot(x='Coping_Struggles', hue='Growing_Stress', data=data)

#plt.title('Growing Stress vs Coping Struggles')
#plt.xlabel('Coping Struggles (Yes/No)')
#plt.ylabel('Count')

#plt.show()

# %%
#plt.figure(figsize=(10,6))
#sns.countplot(x='Days_Indoors', hue='Social_Weakness', data=data)

#plt.title('Social_Weakness vs Days_Indoors')
#plt.xlabel('Days Indoors (1-14 days, Go out every day, etc.)')
#plt.ylabel('Count')

#plt.show()

# %%
#plt.figure(figsize=(10, 6))
#sns.countplot(x='Mental_Health_History', hue='family_history', data=data)


#plt.title('Family History vs Mental Health History')
#plt.xlabel('Mental Health History (Yes/No)')
#plt.ylabel('Count')


#plt.show()

# %%
#plt.figure(figsize=(10, 6))
#sns.countplot(x='Coping_Struggles', hue='Work_Interest', data=data)


#plt.title('Work_Interest vs Coping_Struggles')
#plt.xlabel('Coping Struggles (Yes/No)')
#plt.ylabel('Count')


#plt.show()

# %%
#import seaborn as sns
#import matplotlib.pyplot as plt


#plt.figure(figsize=(18, 12))


#plt.subplot(2, 3, 1)
#sns.countplot(x='Mood_Swings', hue='Gender', data=data)
#plt.title('Gender vs Mood_Swings')


#plt.subplot(2, 3, 2)
#sns.countplot(x='Coping_Struggles', hue='Gender', data=data)
#plt.title('Gender vs Coping_Struggles')


#plt.subplot(2, 3, 3)
#sns.countplot(x='Growing_Stress', hue='Gender', data=data)
#plt.title('Gender vs Growing_Stress')


#plt.tight_layout()


#plt.show()

# %%
#import seaborn as sns
#import matplotlib.pyplot as plt


#plt.figure(figsize=(18, 12))


#plt.subplot(2, 3, 1)
#sns.countplot(x='Mood_Swings', hue='Occupation', data=data)
#plt.title('Occupation vs Mood_Swings')


#plt.subplot(2, 3, 2)
#sns.countplot(x='Coping_Struggles', hue='Occupation', data=data)
#plt.title('Occupation vs Coping_Struggles')

#plt.subplot(2, 3, 3)
#sns.countplot(x='Growing_Stress', hue='self_employed', data=data)
#plt.title('Self_Employed vs Growing_Stress')


#plt.subplot(2, 3, 4)
#sns.countplot(x='Coping_Struggles', hue='self_employed', data=data)
#plt.title('Self_Employed vs Coping_Struggles')


#plt.tight_layout()


#plt.show()

# %% [markdown]
# ### ⚠️ Defining Risk Levels
# Creating a new column **`Risk_Level`** based on treatment status, mental health history, and mood swings to categorize individuals into **High**, **Medium**, or **Low** risk.

# %%
def define_risk(row):
    
    if (row['treatment'] == 'Yes' or
        (row['Mental_Health_History'] == 'Yes' and row['Mood_Swings'] == 'High')):
        return 'High'
        
    if (row['treatment'] == 'No' and
        row['Mental_Health_History'] == 'No' and
        row['Mood_Swings'] == 'Low'):
        return 'Low'
    
    return 'Medium'

data['Risk_Level'] = data.apply(define_risk, axis=1)
print(data['Risk_Level'].value_counts())
# Out:
# Risk_Level
# High      160276
# Medium    112509
# Low        17266
# Name: count, dtype: int64

# %%
#print(data.isna().sum())

# %%
#data.head()

# %%
#print(data['Risk_Level'].unique())

# %%
data['Risk_Level'].value_counts()
# Out:
# Risk_Level
# High      160276
# Medium    112509
# Low        17266
# Name: count, dtype: int64

# %%
eda_data = data.copy()

# %%
#print(data.isna().sum())

# %%
#print(data['Work_Interest'].unique())
#print(data['care_options'].unique())

# %% [markdown]
# ### 🔢 Encoding Categorical Variables
# Converting categorical features into numeric form using **Label Encoding**, **mapping**, and **one-hot encoding** to prepare the dataset for machine learning models.

# %%
from sklearn.preprocessing import LabelEncoder
binary_cols=['Gender','self_employed','family_history','treatment','Coping_Struggles']
for col in binary_cols:
    data[col]=LabelEncoder().fit_transform(data[col])

# %%
data['Days_Indoors']= data['Days_Indoors'].map({'Go out Every day': 0, '1-14 days': 1, '15-30 days': 2, '31-60 days': 3, 'More than 2 months': 4})

# %%
data['Growing_Stress'] = data['Growing_Stress'].map({'No': 0, 'Maybe': 1, 'Yes': 2})
data['Changes_Habits'] = data['Changes_Habits'].map({'No': 0, 'Maybe': 1, 'Yes': 2})
data['Mental_Health_History'] = data['Mental_Health_History'].map({'No': 0, 'Maybe': 1, 'Yes': 2})
data['Mood_Swings'] = data['Mood_Swings'].map({'Low': 0, 'Medium': 1, 'High': 2})
data['Work_Interest'] = data['Work_Interest'].map({'No': 0, 'Maybe': 1, 'Yes': 2})
data['Social_Weakness'] = data['Social_Weakness'].map({'No': 0, 'Maybe': 1, 'Yes': 2})
data['mental_health_interview'] = data['mental_health_interview'].map({'No': 0, 'Maybe': 1, 'Yes': 2})
data['care_options'] = data['care_options'].map({'No': 0, 'Maybe': 1, 'Yes': 2, 'Not sure': 1})

# %%
data = pd.get_dummies(data, columns=['Country', 'Occupation'], drop_first=True)

# %%
data=data.drop(columns=['Timestamp'])
data.head()
# Out:
#    Gender  self_employed  family_history  treatment  Days_Indoors  \
# 0       0              0               0          1             1
# 1       0              0               1          1             1
# 2       0              0               1          1             1
# 3       0              0               1          1             1
# 4       0              0               1          1             1
#
#    Growing_Stress  Changes_Habits  Mental_Health_History  Mood_Swings  \
# 0               2               0                      2            1
# 1               2               0                      2            1
# 2               2               0                      2            1
# 3               2               0                      2            1
# 4               2               0                      2            1
#
#    Coping_Struggles  ...  Country_South Africa  Country_Sweden  \
# 0                 0  ...                 False           False
# ...

# %%
print(data.isna().sum())
# Out:
# Gender                            0
# self_employed                     0
# family_history                    0
# treatment                         0
# Days_Indoors                      0
# Growing_Stress                    0
# Changes_Habits                    0
# Mental_Health_History             0
# Mood_Swings                       0
# Coping_Struggles                  0
# Work_Interest                     0
# Social_Weakness                   0
# mental_health_interview           0
# care_options                      0
# Risk_Level                        0
# Country_Belgium                   0
# Country_Bosnia and Herzegovina    0
# Country_Brazil                    0
# Country_Canada                    0
# Country_Colombia                  0
# Country_Costa Rica                0
# Country_Croatia                   0
# Country_Czech Republic            0
# Country_Denmark                   0
# Country_Finland                   0
# Country_France                    0
# ...

# %%
data.tail()
# Out:
#         Gender  self_employed  family_history  treatment  Days_Indoors  \
# 292359       1              1               1          1             2
# 292360       1              0               1          1             2
# 292361       1              0               1          0             2
# 292362       1              0               1          1             2
# 292363       1              0               1          1             2
#
#         Growing_Stress  Changes_Habits  Mental_Health_History  Mood_Swings  \
# 292359               0               1                      0            0
# 292360               0               1                      0            0
# 292361               0               1                      0            0
# 292362               0               1                      0            0
# 292363               0               1                      0            0
#
#         Coping_Struggles  ...  Country_South Africa  Country_Sweden  \
# ...

# %%
bool_cols = data.select_dtypes('bool').columns
data[bool_cols] = data[bool_cols].astype(int)

# %%
data.head()
# Out:
#    Gender  self_employed  family_history  treatment  Days_Indoors  \
# 0       0              0               0          1             1
# 1       0              0               1          1             1
# 2       0              0               1          1             1
# 3       0              0               1          1             1
# 4       0              0               1          1             1
#
#    Growing_Stress  Changes_Habits  Mental_Health_History  Mood_Swings  \
# 0               2               0                      2            1
# 1               2               0                      2            1
# 2               2               0                      2            1
# 3               2               0                      2            1
# 4               2               0                      2            1
#
#    Coping_Struggles  ...  Country_South Africa  Country_Sweden  \
# 0                 0  ...                     0               0
# ...

# %%
#print(data.columns)

# %%
data[['Risk_Level']].head()
# Out:
#   Risk_Level
# 0       High
# 1       High
# 2       High
# 3       High
# 4       High

# %%
#print(data.isna().sum())

# %% [markdown]
# ### 🤖 Random Forest Classification
# Splitting the dataset into training and testing sets, training a **Random Forest classifier**, and evaluating its performance using a **classification report** and **confusion matrix**.

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report, confusion_matrix
from imblearn.over_sampling import SMOTE


X = data.drop(columns=['Risk_Level', 'treatment'])
y = data['Risk_Level']



X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42, stratify=y)





rf_model = RandomForestClassifier(n_estimators=100,max_depth=15,random_state=42,class_weight='balanced')
rf_model.fit(X_train, y_train)

y_pred = rf_model.predict(X_test)

print("Classification Report:\n", classification_report(y_test, y_pred))
print("Confusion Matrix:\n", confusion_matrix(y_test, y_pred))
# Out:
# Classification Report:
#                precision    recall  f1-score   support
#
#         High       0.81      0.66      0.73     48083
#          Low       0.54      0.99      0.70      5180
#       Medium       0.69      0.78      0.73     33753
#
#     accuracy                           0.73     87016
#    macro avg       0.68      0.81      0.72     87016
# weighted avg       0.75      0.73      0.73     87016
#
# Confusion Matrix:
#  [[31891  4440 11752]
#  [   49  5131     0]
#  [ 7362     0 26391]]

# %% [markdown]
# ### 🔍 Model Explainability with SHAP
# Using **SHAP** to interpret the Random Forest model and visualize feature importance for a sample of test data.

# %%
#import shap

#X_test_sample = X_test.sample(n=500, random_state=42)
#print(X_test_sample.shape)
#explainer_rf = shap.TreeExplainer(rf_model)
#shap_values_rf = explainer_rf.shap_values(X_test_sample)
#shap.summary_plot(shap_values_rf, X_test_sample, plot_type="bar")

# %% [markdown]
# ### ⚡ AdaBoost Classification
# Training an **AdaBoost classifier** with decision trees as base estimators and evaluating its performance using a **classification report** and **confusion matrix**.

# %%
from sklearn.ensemble import AdaBoostClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import classification_report, confusion_matrix

ada_model = AdaBoostClassifier(
    estimator=DecisionTreeClassifier(max_depth=3), n_estimators=200, learning_rate=0.5
)

ada_model.fit(X_train, y_train)

y_pred_ada = ada_model.predict(X_test)

print("AdaBoost Classification Report:\n", classification_report(y_test, y_pred_ada))
print("AdaBoost Confusion Matrix:\n", confusion_matrix(y_test, y_pred_ada))
# Out:
# AdaBoost Classification Report:
#                precision    recall  f1-score   support
#
#         High       0.76      0.81      0.78     48083
#          Low       0.75      0.61      0.67      5180
#       Medium       0.74      0.70      0.72     33753
#
#     accuracy                           0.75     87016
#    macro avg       0.75      0.71      0.73     87016
# weighted avg       0.75      0.75      0.75     87016
#
# AdaBoost Confusion Matrix:
#  [[38772  1020  8291]
#  [ 2040  3140     0]
#  [ 9998     0 23755]]

# %% [markdown]
# ### 🔍 AdaBoost Model Explainability with SHAP
# Applying **SHAP KernelExplainer** to interpret the AdaBoost model and visualize the impact of each feature on predictions.

# %%
#import shap
#import numpy as np

#X_test_sample = X_test.sample(n=100, random_state=42)

#def predict_fn(X):
    #return ada_model.predict_proba(X)

#explainer_ada = shap.KernelExplainer(predict_fn, X_test_sample)
#shap_values_ada = explainer_ada.shap_values(X_test_sample)
#shap.summary_plot(shap_values_ada, X_test_sample, plot_type="bar")

# %% [markdown]
# ### 🌱 Gradient Boosting Classification
# Training a **Gradient Boosting classifier** and evaluating its performance using a **classification report** and **confusion matrix** for the risk level prediction.

# %%
from sklearn.ensemble import GradientBoostingClassifier
from imblearn.over_sampling import SMOTE
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, confusion_matrix


X = data.drop(columns=['Risk_Level', 'treatment'])
y = data['Risk_Level']


X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42, stratify=y)



gb_model = GradientBoostingClassifier(n_estimators=200, max_depth=8, learning_rate=0.1, random_state=42)


gb_model.fit(X_train, y_train)


y_pred = gb_model.predict(X_test)

print("\n--- Gradient Boosting Classification Report ---\n", classification_report(y_test, y_pred))
print("Gradient Boosting Confusion Matrix:\n", confusion_matrix(y_test, y_pred))
# Out:
# --- Gradient Boosting Classification Report ---
#                precision    recall  f1-score   support
#
#         High       0.79      0.86      0.82     48083
#          Low       0.79      0.72      0.75      5180
#       Medium       0.80      0.71      0.76     33753
#
#     accuracy                           0.79     87016
#    macro avg       0.79      0.76      0.78     87016
# weighted avg       0.79      0.79      0.79     87016
#
# Gradient Boosting Confusion Matrix:
#  [[41247   986  5850]
#  [ 1456  3724     0]
#  [ 9708     0 24045]]

# %% [markdown]
# ### 🔍 Gradient Boosting Explainability with SHAP
# Using **SHAP KernelExplainer** to interpret the Gradient Boosting model and visualize the contribution of each feature to predictions.

# %%
#import shap
#import numpy as np
#import pandas as pd

#X_test_sample = X_test.sample(n=50, random_state=42)
#explainer_gb = shap.KernelExplainer(gb_model.predict_proba, shap.sample(X_res, 50, random_state=42))
#shap_values_gb = explainer_gb.shap_values(X_test_sample, nsamples=100)
#shap.summary_plot(shap_values_gb, X_test_sample, plot_type="bar")

# %% [markdown]
# ### ⚡ XGBoost Classification
# Training an **XGBoost classifier** for multi-class risk level prediction and evaluating its performance using a **classification report** and **confusion matrix**.

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, confusion_matrix
from imblearn.over_sampling import SMOTE
import xgboost as xgb

def define_risk(row):

    if (row['treatment'] == 1 or 
        (row['Mental_Health_History'] == 2 and row['Mood_Swings'] == 2)):
        return 'High'
        
    if (row['treatment'] == 0 and 
        row['Mental_Health_History'] == 0 and 
        row['Mood_Swings'] == 0):
        return 'Low'
    
    return 'Medium'

bool_cols = data.select_dtypes('bool').columns
data[bool_cols] = data[bool_cols].astype(int)

X = data.drop(columns=['Risk_Level', 'treatment'])
y = data['Risk_Level']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42, stratify=y)



label_map = {'Low': 0, 'Medium': 1, 'High': 2}
y_train_xgb = y_train.map(label_map)
y_test_xgb = y_test.map(label_map)

xgb_model = xgb.XGBClassifier(
    objective='multi:softmax',
    num_class=3,
    n_estimators=200,
    max_depth=10,
    learning_rate=0.05,
    eval_metric='merror', 
    use_label_encoder=False,
    random_state=42,
   
    n_jobs=-1
)


xgb_model.fit(X_train, y_train_xgb)

y_pred_xgb_int = xgb_model.predict(X_test)

reverse_label_map = {0: 'Low', 1: 'Medium', 2: 'High'}
y_pred_xgb = pd.Series(y_pred_xgb_int).map(reverse_label_map)

print("\n--- XGBoost Classification Report ---\n", classification_report(y_test, y_pred_xgb))
print("XGBoost Confusion Matrix:\n", confusion_matrix(y_test, y_pred_xgb))
# Out:
# C:\Users\user\anaconda3\Lib\site-packages\xgboost\training.py:183: UserWarning: [19:32:05] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# --- XGBoost Classification Report ---
#                precision    recall  f1-score   support
#
#         High       0.79      0.87      0.82     48083
#          Low       0.80      0.72      0.76      5180
#       Medium       0.81      0.71      0.76     33753
#
#     accuracy                           0.80     87016
#    macro avg       0.80      0.76      0.78     87016
# weighted avg       0.80      0.80      0.79     87016
#
# XGBoost Confusion Matrix:
#  [[41621   919  5543]
#  [ 1438  3742     0]
#  [ 9919     0 23834]]

# %% [markdown]
# ### 🔍 XGBoost Model Explainability with SHAP
# Using **SHAP TreeExplainer** to interpret the XGBoost model and visualize feature importance for the test data sample.

# %%
import shap

X_test_sample = X_test.sample(n=200, random_state=42)

explainer_xgb = shap.TreeExplainer(xgb_model)
shap_values_xgb = explainer_xgb.shap_values(X_test_sample)
shap.summary_plot(shap_values_xgb, X_test_sample, plot_type="bar")

# %%
import shap

shap.initjs()
used_features = xgb_model.get_booster().feature_names
print(used_features)
# Out:
# <div align='center'><img src='data:image/png;base64,...' /></div><script charset='utf-8'>/*! For license information please see bundle.js.LICENSE.txt */
# ...

# %%
import shap

# Initialize JS visualization
shap.initjs()

# Take a sample of the test set (optional, speeds up plotting)
X_test_sample = X_test.sample(n=200, random_state=42)

# Only keep features actually used by the model
used_features = xgb_model.get_booster().feature_names
X_used = X_test_sample[used_features]

# Create SHAP explainer
explainer = shap.TreeExplainer(xgb_model)
shap_values_list = explainer.shap_values(X_used)  # list of arrays, one per class

# Choose class to explain
class_idx = 2  # 0=Low, 1=Medium, 2=High risk

# Choose a feature to plot (must be in used_features)
feature_to_plot = "Mood_Swings"

# Generate SHAP dependence plot
shap.dependence_plot(feature_to_plot, shap_values_list[class_idx], X_used)
# Out:
# <div align='center'><img src='data:image/png;base64,...' /></div><script charset='utf-8'>/*! For license information please see bundle.js.LICENSE.txt */
# ...

# %% [markdown]
# ### 🐱 CatBoost Classification
# Training a **CatBoost classifier** for risk level prediction and evaluating its performance using a **classification report** and **confusion matrix**.

# %%
#pip install catboost

# %%
from catboost import CatBoostClassifier
from imblearn.over_sampling import SMOTE
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, confusion_matrix
import pandas as pd

def define_risk(row):
    if (row['treatment'] == 1 or 
        (row['Mental_Health_History'] == 2 and row['Mood_Swings'] == 2)):
        return 'High'
    if (row['treatment'] == 0 and 
        row['Mental_Health_History'] == 0 and 
        row['Mood_Swings'] == 0):
        return 'Low'
    return 'Medium'

bool_cols = data.select_dtypes('bool').columns
data[bool_cols] = data[bool_cols].astype(int)

X = data.drop(columns=['Risk_Level', 'treatment'])
y = data['Risk_Level']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42, stratify=y)





label_map = {'Low': 0, 'Medium': 1, 'High': 2}
y_train_catboost = y_train.map(label_map)
y_test_catboost = y_test.map(label_map)


catboost_model = CatBoostClassifier(
    iterations=400,          
    depth=10,                 
    learning_rate=0.05,       
    cat_features=[],          
    random_state=42,          
    verbose=200               
)


catboost_model.fit(X_train, y_train_catboost)


y_pred_catboost = catboost_model.predict(X_test)
y_pred_catboost_flattened = y_pred_catboost.flatten()

reverse_label_map = {0: 'Low', 1: 'Medium', 2: 'High'}
y_pred_catboost_labels = pd.Series(y_pred_catboost_flattened).map(reverse_label_map)


print("\n--- CatBoost Classification Report ---\n", classification_report(y_test, y_pred_catboost_labels))
print("CatBoost Confusion Matrix:\n", confusion_matrix(y_test, y_pred_catboost_labels))
# Out:
# 0:	learn: 1.0525351	total: 356ms	remaining: 2m 22s
# 200:	learn: 0.4113092	total: 27.2s	remaining: 27s
# 399:	learn: 0.3910156	total: 53.9s	remaining: 0us
#
# --- CatBoost Classification Report ---
#                precision    recall  f1-score   support
#
#         High       0.79      0.86      0.82     48083
#          Low       0.80      0.72      0.76      5180
#       Medium       0.81      0.71      0.76     33753
#
#     accuracy                           0.80     87016
#    macro avg       0.80      0.77      0.78     87016
# weighted avg       0.80      0.80      0.79     87016
#
# CatBoost Confusion Matrix:
#  [[41496   927  5660]
#  [ 1443  3737     0]
#  [ 9702     0 24051]]

# %% [markdown]
# ### 🔍 CatBoost Model Explainability with SHAP
# Using **SHAP TreeExplainer** to interpret the CatBoost model and visualize the contribution of each feature to predictions.

# %%
#import shap
#X_test_sample = X_test.sample(n=200, random_state=42)
#explainer_cb = shap.TreeExplainer(catboost_model)
#shap_values_cb = explainer_cb.shap_values(X_test_sample)
#shap.summary_plot(shap_values_cb, X_test_sample, plot_type="bar")

# %% [markdown]
# ### 💡 LightGBM Classification
# Training a **LightGBM classifier** for multi-class risk level prediction and evaluating its performance using a **classification report** and **confusion matrix**.

# %%
#!pip install lightgbm

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, confusion_matrix


import lightgbm as lgb


X = data.drop(columns=['Risk_Level', 'treatment'])
y = data['Risk_Level']


X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42, stratify=y)

print("--- Data Split Summary ---")
print("Original training distribution:\n", y_train.value_counts())



label_map = {'Low': 0, 'Medium': 1, 'High': 2}
y_train_lgbm = y_train.map(label_map)
y_test_lgbm = y_test.map(label_map) 


lgbm_model = lgb.LGBMClassifier(
    objective='multiclass',
    num_class=3,
    n_estimators=400,
    max_depth=20,
    learning_rate=0.05,
    metric='multi_logloss',
    random_state=42,
    n_jobs=-1
)

print("\nFitting LightGBM Model on Original Data (No SMOTE)...")

lgbm_model.fit(X_train, y_train_lgbm)

y_pred_lgbm_int = lgbm_model.predict(X_test)


reverse_label_map = {0: 'Low', 1: 'Medium', 2: 'High'}
y_pred_lgbm = pd.Series(y_pred_lgbm_int).map(reverse_label_map)

print("\n--- LightGBM Classification Report (No SMOTE) ---\n", classification_report(y_test, y_pred_lgbm))
print("LightGBM Confusion Matrix (No SMOTE):\n", confusion_matrix(y_test, y_pred_lgbm))
# Out:
# --- Data Split Summary ---
# Original training distribution:
#  Risk_Level
# High      112193
# Medium     78756
# Low        12086
# Name: count, dtype: int64
#
# Fitting LightGBM Model on Original Data (No SMOTE)...
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.008502 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 113
# [LightGBM] [Info] Number of data points in the train set: 203035, number of used features: 51
# [LightGBM] [Info] Start training from score -2.821331
# [LightGBM] [Info] Start training from score -0.947024
# [LightGBM] [Info] Start training from score -0.593158
#
# --- LightGBM Classification Report (No SMOTE) ---
#                precision    recall  f1-score   support
#
# ...

# %% [markdown]
# ### 📈 LightGBM Learning Curve
# Analyzing **model performance** with varying training set sizes by plotting **F1 scores** and **accuracy** for both training and validation sets.

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import f1_score, accuracy_score
import lightgbm as lgb

# Define training set sizes for the learning curve
train_sizes = [50000, 100000, 150000, 200000, 250000, X_train.shape[0]]

train_f1, val_f1 = [], []
train_acc, val_acc = [], []

for size in train_sizes:
    # Ensure sample size does not exceed available training rows
    n = min(size, len(X_train))
    
    # Sample subset of training data
    X_subset = X_train.sample(n=n, random_state=42)
    y_subset = y_train_lgbm.loc[X_subset.index]
    
    # Initialize LightGBM model
    model = lgb.LGBMClassifier(
        objective='multiclass',
        num_class=3,
        n_estimators=400,
        max_depth=20,
        learning_rate=0.05,
        random_state=42,
        n_jobs=-1
    )
    
    # Fit model
    model.fit(X_subset, y_subset)
    
    # Predict on training subset and full validation set
    y_train_pred = model.predict(X_subset)
    y_val_pred = model.predict(X_test)
    
    # Compute weighted F1
    train_f1.append(f1_score(y_subset, y_train_pred, average='weighted'))
    val_f1.append(f1_score(y_test_lgbm, y_val_pred, average='weighted'))
    
    # Compute accuracy
    train_acc.append(accuracy_score(y_subset, y_train_pred))
    val_acc.append(accuracy_score(y_test_lgbm, y_val_pred))

# Plot Learning Curves
plt.figure(figsize=(10,6))
plt.plot(train_sizes, train_f1, 'o-', color='blue', label='Training F1')
plt.plot(train_sizes, val_f1, 'o-', color='green', label='Validation F1')
plt.plot(train_sizes, train_acc, 's--', color='cyan', label='Training Accuracy')
plt.plot(train_sizes, val_acc, 's--', color='lime', label='Validation Accuracy')
plt.xlabel("Training Set Size")
plt.ylabel("Score")
plt.title("LightGBM Learning Curve (F1 & Accuracy)")
plt.legend()
plt.grid(True)
plt.show()

# %%
#mood_col = 'Mood_Swings'
#mh_col = 'Mental_Health_History'


#_test_reset = X_test.reset_index(drop=True)


#mask = (X_test_reset[mood_col] == 2) & (X_test_reset[mh_col] == 2)


#preds_for_masked = y_pred_lgbm[mask.values]  


#problematic_cases = preds_for_masked[preds_for_masked != 'High']

#print(f"Total cases with Mood_Swings=High & Mental_Health_History=Yes: {mask.sum()}")
#print(f"Number of cases where model did NOT predict High: {len(problematic_cases)}")

#if len(problematic_cases) > 0:
    #print("\nThese cases had unexpected predictions:")
    #display(X_test_reset[mask].assign(Predicted_Risk=preds_for_masked)[preds_for_masked != 'High'])
#else:
    #print("\n✅ All cases with Mood_Swings=High & Mental_Health_History=Yes were predicted as High.")

# %%
#y_pred_int = lgbm_model.predict(X_test)
#reverse_label_map = {0: 'Low', 1: 'Medium', 2: 'High'}
#y_pred = pd.Series(y_pred_int).map(reverse_label_map)


#results_df = X_test.copy()
#results_df["True_Label"] = y_test   # ✅ fixed
#results_df["Pred_Label"] = y_pred.values


#low_case = results_df[results_df["Pred_Label"] == "Low"].head(1)

#print("✅ Example of a prediction = 'Low'")
#display(low_case)

# %%
#row_idx = 162259	
#data.loc[row_idx, [c for c in data.columns if c.startswith('Country_') or c.startswith('Occupation_')]]

# %%
#data.loc[row_idx, ["care_options"]]

# %%
#row_idx = 162259	
#row = X_test.loc[[row_idx]]  


#probs = lgbm_model.predict_proba(row)[0]

#print("Index -> Probability mapping:")
#for i, p in enumerate(probs):
    #print(f"{i}: {p:.4f}")


#pred_int = int(np.argmax(probs))
#reverse_label_map = {0: 'Low', 1: 'Medium', 2: 'High'}
#print(f"\nPredicted index = {pred_int}  →  {reverse_label_map[pred_int]}")

# %%
#import shap
#import numpy as np

#X_test_sample = X_test.sample(n=200, random_state=42)
#explainer_lgbm = shap.TreeExplainer(lgbm_model)
#shap_values_lgbm = explainer_lgbm.shap_values(X_test_sample)
#shap.summary_plot(shap_values_lgbm, X_test_sample, plot_type="bar")

# %% [markdown]
# ### 🧩 Stacked Ensemble Classification
# Building a **stacked ensemble model** using LightGBM, XGBoost, and CatBoost as base learners with **Logistic Regression** as the meta-learner, and evaluating its performance on the test set.

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from imblearn.over_sampling import SMOTE
from sklearn.preprocessing import LabelEncoder
from lightgbm import LGBMClassifier
from xgboost import XGBClassifier
from catboost import CatBoostClassifier
from sklearn.ensemble import StackingClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report, accuracy_score


X = data.drop(columns=['Risk_Level', 'treatment', 'Mental_Health_History', 'Mood_Swings'])
y = data['Risk_Level']

le_target = LabelEncoder()
y = le_target.fit_transform(y)
class_names = le_target.classes_
print(f"Target classes encoded: {class_names} mapped to {le_target.transform(class_names)}")



X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42, stratify=y)



print("Data preparation complete. X_res, y_res, X_test, y_test are defined.")



print("Re-training base models (LightGBM, XGBoost, CatBoost)...")
lgbm_model = LGBMClassifier(random_state=42, n_jobs=-1, verbosity=-1)
lgbm_model.fit(X_train, y_train)

xgb_model = XGBClassifier(random_state=42, n_jobs=-1)
xgb_model.fit(X_train, y_train)

cb_model = CatBoostClassifier(random_state=42, verbose=0, thread_count=-1, loss_function='MultiClass')
cb_model.fit(X_train, y_train)

print("Base models training complete.")

base_estimators = [
    ('lgbm', lgbm_model),
    ('xgb', xgb_model),
    ('catboost', cb_model)
]

final_estimator = LogisticRegression(max_iter=1000, random_state=42, solver='lbfgs')

stacked_model = StackingClassifier(
    estimators=base_estimators,
    final_estimator=final_estimator,
    cv=5,
    n_jobs=-1
)

print("Starting training for the Stacked Ensemble...")
stacked_model.fit(X_train, y_train)
print("Stacked Ensemble training complete.")

y_pred_stack = stacked_model.predict(X_test)

stack_accuracy = accuracy_score(y_test, y_pred_stack)
print(f"\n==================================================")
print(f"FINAL STACKED ENSEMBLE PERFORMANCE")
print(f"==================================================")
print(f"Stacked Ensemble Accuracy: {stack_accuracy:.4f}")

print("\nStacked Ensemble Classification Report:")
print(classification_report(y_test, y_pred_stack, digits=4, target_names=class_names))
# Out:
# Target classes encoded: ['High' 'Low' 'Medium'] mapped to [0 1 2]
# Data preparation complete. X_res, y_res, X_test, y_test are defined.
# Re-training base models (LightGBM, XGBoost, CatBoost)...
# Base models training complete.
# Starting training for the Stacked Ensemble...
# Stacked Ensemble training complete.
#
# ...
# FINAL STACKED ENSEMBLE PERFORMANCE
# ...
# Stacked Ensemble Accuracy: 0.7845
#
# Stacked Ensemble Classification Report:
#               precision    recall  f1-score   support
#
#         High     0.7796    0.8539    0.8151     48083
#          Low     0.7588    0.6954    0.7257      5180
#       Medium     0.7975    0.6993    0.7452     33753
#
#     accuracy                         0.7845     87016
#    macro avg     0.7786    0.7495    0.7620     87016
# weighted avg     0.7853    0.7845    0.7826     87016

# %% [markdown]
# ### 🗳️ Voting Classifier
# Training a **soft voting ensemble** combining LightGBM, XGBoost, and CatBoost, and evaluating its performance on the test set.

# %%
from sklearn.ensemble import VotingClassifier
from sklearn.metrics import classification_report, accuracy_score


estimators = [
    ('lgbm', lgbm_model),
    ('xgb', xgb_model),
    ('catboost', cb_model)
]

voting_model = VotingClassifier(
    estimators=estimators,
    voting='soft',
    n_jobs=-1
)

print("Starting training for the Voting Classifier (fast fit)...")

voting_model.fit(X_train, y_train)

print("Voting Classifier training complete.")
y_pred_vote = voting_model.predict(X_test)
vote_accuracy = accuracy_score(y_test, y_pred_vote)
print(f"\n==================================================")
print(f"FINAL VOTING CLASSIFIER PERFORMANCE")
print(f"==================================================")
print(f"Voting Classifier Accuracy: {vote_accuracy:.4f}")
print("\nVoting Classifier Classification Report:")
print(classification_report(y_test, y_pred_vote, digits=4, target_names=class_names))
# Out:
# Starting training for the Voting Classifier (fast fit)...
# Voting Classifier training complete.
#
# ...
# FINAL VOTING CLASSIFIER PERFORMANCE
# ...
# Voting Classifier Accuracy: 0.7832
#
# Voting Classifier Classification Report:
#               precision    recall  f1-score   support
#
#         High     0.7776    0.8613    0.8173     48083
#          Low     0.8020    0.6413    0.7127      5180
#       Medium     0.7907    0.6938    0.7391     33753
#
#     accuracy                         0.7832     87016
#    macro avg     0.7901    0.7321    0.7564     87016
# weighted avg     0.7841    0.7832    0.7808     87016

# %% [markdown]
# ### 📊 Model Comparison
# Training multiple models (Random Forest, AdaBoost, Gradient Boosting, XGBoost, CatBoost, LightGBM, Stacking, and Voting Ensembles) and comparing their **F1-scores** and **overall accuracy** on the test set.

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import classification_report, accuracy_score
from sklearn.ensemble import RandomForestClassifier, AdaBoostClassifier, GradientBoostingClassifier, StackingClassifier, VotingClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.linear_model import LogisticRegression
from lightgbm import LGBMClassifier
from xgboost import XGBClassifier
from catboost import CatBoostClassifier


X = data.drop(columns=['Risk_Level', 'treatment'])
y = data['Risk_Level']


le = LabelEncoder()
y_enc = le.fit_transform(y)
class_names = le.classes_


X_train, X_test, y_train, y_test = train_test_split(
    X, y_enc, test_size=0.3, random_state=42, stratify=y_enc
)


rf_model = RandomForestClassifier(n_estimators=100, max_depth=15, random_state=42, class_weight='balanced')
rf_model.fit(X_train, y_train)
y_pred_rf = rf_model.predict(X_test)


ada_model = AdaBoostClassifier(
    estimator=DecisionTreeClassifier(max_depth=3), n_estimators=200, learning_rate=0.5, random_state=42
)
ada_model.fit(X_train, y_train)
y_pred_ada = ada_model.predict(X_test)


gb_model = GradientBoostingClassifier(n_estimators=200, max_depth=8, learning_rate=0.1, random_state=42)
gb_model.fit(X_train, y_train)
y_pred_gb = gb_model.predict(X_test)


xgb_model = XGBClassifier(objective='multi:softmax', num_class=len(class_names), n_estimators=200, max_depth=10, learning_rate=0.05, eval_metric='merror', use_label_encoder=False, random_state=42, n_jobs=-1)
xgb_model.fit(X_train, y_train)
y_pred_xgb = xgb_model.predict(X_test)


cb_model = CatBoostClassifier(iterations=400, depth=10, learning_rate=0.05, verbose=0, random_state=42)
cb_model.fit(X_train, y_train)
y_pred_cb = cb_model.predict(X_test).flatten()


lgbm_model = LGBMClassifier(objective='multiclass', num_class=len(class_names), n_estimators=400, max_depth=20, learning_rate=0.05, random_state=42, n_jobs=-1)
lgbm_model.fit(X_train, y_train)
y_pred_lgbm = lgbm_model.predict(X_test)


base_estimators = [
    ('lgbm', LGBMClassifier(random_state=42, n_jobs=-1)),
    ('xgb', XGBClassifier(random_state=42, n_jobs=-1)),
    ('catboost', CatBoostClassifier(random_state=42, verbose=0, thread_count=-1, loss_function='MultiClass'))
]
stacked_model = StackingClassifier(
    estimators=base_estimators,
    final_estimator=LogisticRegression(max_iter=1000, random_state=42, solver='lbfgs'),
    cv=5,
    n_jobs=-1
)
stacked_model.fit(X_train, y_train)
y_pred_stack = stacked_model.predict(X_test)


voting_model = VotingClassifier(
    estimators=base_estimators,
    voting='soft',
    n_jobs=-1
)
voting_model.fit(X_train, y_train)
y_pred_vote = voting_model.predict(X_test)

--
models = [
    ('Random Forest', y_pred_rf),
    ('AdaBoost', y_pred_ada),
    ('Gradient Boosting', y_pred_gb),
    ('XGBoost', y_pred_xgb),
    ('CatBoost', y_pred_cb),
    ('LightGBM', y_pred_lgbm),
    ('Stacking Ensemble', y_pred_stack),
    ('Voting Ensemble', y_pred_vote)
]


dfs = []
for name, y_pred_model in models:
    report = classification_report(y_test, y_pred_model, output_dict=True)
    df = pd.DataFrame(report).transpose()
    df['model'] = name
    dfs.append(df)

comparison_df = pd.concat(dfs)
comparison_df.reset_index(inplace=True)
comparison_df.rename(columns={'index':'class'}, inplace=True)


summary_df = comparison_df[['model', 'class', 'f1-score']].copy()
accuracy_df = comparison_df[comparison_df['class']=='accuracy'][['model', 'f1-score']].copy()
accuracy_df.rename(columns={'f1-score':'accuracy'}, inplace=True)

print("F1-score per class for all models:\n", summary_df)
print("\nOverall accuracy per model:\n", accuracy_df)
# Out:
# C:\Users\user\anaconda3\Lib\site-packages\xgboost\training.py:183: UserWarning: [19:49:34] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# F1-score per class for all models:
#                  model         class  f1-score
# 0       Random Forest             0  0.729896
# 1       Random Forest             1  0.695682
# 2       Random Forest             2  0.734144
# 3       Random Forest      accuracy  0.728751
# 4       Random Forest     macro avg  0.719907
# 5       Random Forest  weighted avg  0.729507
# 6            AdaBoost             0  0.784120
# 7            AdaBoost             1  0.672377
# 8            AdaBoost             2  0.722047
# 9            AdaBoost      accuracy  0.754654
# 10           AdaBoost     macro avg  0.726182
# 11           AdaBoost  weighted avg  0.753391
# 12  Gradient Boosting             0  0.820885
# ...

# %% [markdown]
# ### 📊 Visualization of Model Performance
# Comparing models visually by plotting **overall accuracy** and **F1-score per class** to identify the best-performing algorithms.

# %%
import matplotlib.pyplot as plt
import seaborn as sns


plt.figure(figsize=(10,6))
sns.barplot(data=accuracy_df, x='model', y='accuracy', palette='viridis')
plt.xticks(rotation=45, ha='right')
plt.title("Overall Accuracy Comparison of Models")
plt.ylabel("Accuracy")
plt.xlabel("Model")
plt.ylim(0.7, 0.82)
plt.show()


f1_class_df = f1_df[f1_df['class'].isin([0,1,2])]  # Only class-level F1
plt.figure(figsize=(12,6))
sns.barplot(data=f1_class_df, x='model', y='f1-score', hue='class', palette='coolwarm')
plt.xticks(rotation=45, ha='right')
plt.title("F1-Score per Class for Each Model")
plt.ylabel("F1-Score")
plt.xlabel("Model")
plt.legend(title='Class', labels=['High', 'Low', 'Medium'])
plt.ylim(0.6, 0.85)
plt.show()
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_13324\1006325988.py:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=accuracy_df, x='model', y='accuracy', palette='viridis')
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[74], line 15
#      12 plt.show()
#      14 # F1-score per class comparison
# ---> 15 f1_class_df = f1_df[f1_df['class'].isin([0,1,2])]  # Only class-level F1
#      16 plt.figure(figsize=(12,6))
#      17 sns.barplot(data=f1_class_df, x='model', y='f1-score', hue='class', palette='coolwarm')
#
# NameError: name 'f1_df' is not defined

# %% [markdown]
# ### 📈 ROC Curves for All Models
# Plotting **ROC curves** for each model to evaluate their performance across all classes and visualize class-wise discriminative ability.

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import roc_curve, auc
from sklearn.preprocessing import label_binarize
import numpy as np


y_test_bin = label_binarize(y_test, classes=np.arange(len(class_names)))


model_probs = {
    'Random Forest': rf_model.predict_proba(X_test),
    'AdaBoost': ada_model.predict_proba(X_test),
    'Gradient Boosting': gb_model.predict_proba(X_test),
    'XGBoost': xgb_model.predict_proba(X_test),
    'CatBoost': cb_model.predict_proba(X_test),
    'LightGBM': lgbm_model.predict_proba(X_test),
    'Stacking Ensemble': stacked_model.predict_proba(X_test),
    'Voting Ensemble': voting_model.predict_proba(X_test)
}


plt.figure(figsize=(15,12))

for i, (model_name, y_score) in enumerate(model_probs.items(), 1):
    plt.subplot(3, 3, i)
    
    for j, class_name in enumerate(class_names):
        fpr, tpr, _ = roc_curve(y_test_bin[:, j], y_score[:, j])
        roc_auc = auc(fpr, tpr)
        plt.plot(fpr, tpr, label=f'{class_name} (AUC={roc_auc:.2f})')
    
    plt.plot([0, 1], [0, 1], 'k--')
    plt.title(f'ROC Curve - {model_name}')
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.legend(loc='lower right', fontsize=8)

plt.tight_layout()
plt.show()

# %% [markdown]
# ### 🔥 Heatmap of F1-Scores
# Visualizing **class-wise F1-scores** for all models using a heatmap to easily compare performance across models and classes.

# %%
import seaborn as sns
import matplotlib.pyplot as plt


f1_class_df = summary_df[summary_df['class'].isin(['0','1','2'])].copy()


heatmap_data = f1_class_df.pivot(index='class', columns='model', values='f1-score')


plt.figure(figsize=(12,6))
sns.heatmap(heatmap_data, annot=True, fmt=".2f", cmap="YlGnBu", cbar_kws={'label': 'F1-Score'})
plt.title("F1-Score per Class Across Models")
plt.xlabel("Model")
plt.ylabel("Class")
plt.yticks(ticks=[0.5,1.5,2.5], labels=['High', 'Low', 'Medium'], rotation=0)  # Optional: friendly class names
plt.xticks(rotation=45, ha='right')
plt.show()

# %% [markdown]
# ### 🧮 Confusion Matrices for All Models
# Plotting **confusion matrices** for each model to visualize class-wise prediction performance and misclassifications.

# %%
y_pred_cb = cb_model.predict(X_test).astype(int).flatten()  
y_pred_stack = stacked_model.predict(X_test).astype(int)
y_pred_vote = voting_model.predict(X_test).astype(int)

# %%
y_pred_cb = cb_model.predict(X_test).astype(int).flatten()
y_pred_stack = stacked_model.predict(X_test).astype(int)
y_pred_vote = voting_model.predict(X_test).astype(int)

# %%
models = [
    ('Random Forest', y_pred_rf),
    ('AdaBoost', y_pred_ada),
    ('Gradient Boosting', y_pred_gb),
    ('XGBoost', y_pred_xgb),
    ('CatBoost', y_pred_cb),
    ('LightGBM', y_pred_lgbm),
    ('Stacking Ensemble', y_pred_stack),
    ('Voting Ensemble', y_pred_vote)
]

# %%
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import confusion_matrix

n_models = len(models)
cols = 4  
rows = (n_models + cols - 1) // cols 

fig, axes = plt.subplots(rows, cols, figsize=(5*cols, 4*rows))
axes = axes.flatten() 

for i, (name, y_pred_model) in enumerate(models):
    cm = confusion_matrix(y_test, y_pred_model)
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', 
                xticklabels=class_names, yticklabels=class_names, ax=axes[i])
    axes[i].set_title(f'{name}')
    axes[i].set_ylabel('Actual')
    axes[i].set_xlabel('Predicted')


for j in range(i+1, len(axes)):
    fig.delaxes(axes[j])

plt.tight_layout()
plt.show()

# %% [markdown]
# ### 💾 Saving Model and Artifacts for Deployment
# Saving the **final LightGBM model**, **label encoder**, **class names**, **feature names**, **SHAP explainer**, a sample of test data, and **UI value mappings** using `joblib` for deployment.

# %%
import os
import joblib
import shap
from sklearn.preprocessing import LabelEncoder  



final_model_to_deploy = lgbm_model
joblib.dump(final_model_to_deploy, 'lgbm_model.joblib')


le_target = LabelEncoder()
le_target.fit(['Low', 'Medium', 'High'])  
joblib.dump(le_target, 'label_encoder.joblib')
joblib.dump(list(le_target.classes_), 'class_names.joblib') 


feature_names = list(X.columns)
joblib.dump(feature_names, 'feature_names.joblib')


explainer = shap.TreeExplainer(final_model_to_deploy)
joblib.dump(explainer, 'shap_explainer.joblib')


X_sample = X_test.head(100).copy()
if not hasattr(X_sample, "columns"):  # if it's ndarray for any reason
    import pandas as pd
    X_sample = pd.DataFrame(X_sample, columns=feature_names)
joblib.dump(X_sample, 'X_sample.joblib')

print("✅ Saved: lgbm_model, label_encoder, class_names, feature_names, shap_explainer, X_sample")
# Out:
# ✅ Saved: lgbm_model, label_encoder, class_names, feature_names, shap_explainer, X_sample

# %%
import joblib

ui_value_maps = {
  
    "Gender": [("Female", 0), ("Male", 1)],
    "self_employed": [("No", 0), ("Yes", 1)],
    "family_history": [("No", 0), ("Yes", 1)],
    "treatment": [("No", 0), ("Yes", 1)],
    "Coping_Struggles": [("No", 0), ("Yes", 1)],

    
    "Days_Indoors": [
        ("Go out Every day", 0),
        ("1-14 days", 1),
        ("15-30 days", 2),
        ("31-60 days", 3),
        ("More than 2 months", 4)
    ],
    "Growing_Stress": [
        ("No", 0),
        ("Maybe", 1),
        ("Yes", 2)
    ],
    "Changes_Habits": [
        ("No", 0),
        ("Maybe", 1),
        ("Yes", 2)
    ],
    "Mental_Health_History": [
        ("No", 0),
        ("Maybe", 1),
        ("Yes", 2)
    ],
    "Mood_Swings": [
        ("Low", 0),
        ("Medium", 1),
        ("High", 2)
    ],
    "Work_Interest": [
        ("No", 0),
        ("Maybe", 1),
        ("Yes", 2)
    ],
    "Social_Weakness": [
        ("No", 0),
        ("Maybe", 1),
        ("Yes", 2)
    ],
    "mental_health_interview": [
        ("No", 0),
        ("Maybe", 1),
        ("Yes", 2)
    ],
    "care_options": [
        ("No", 0),
        ("Maybe", 1),
        ("Not sure", 1),
        ("Yes", 2)
    ]
}

joblib.dump(ui_value_maps, "ui_value_maps.joblib")
print("✅ ui_value_maps.joblib saved successfully!")
# Out:
# ✅ ui_value_maps.joblib saved successfully!
